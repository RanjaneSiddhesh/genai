# %% [markdown]
# <a href="https://colab.research.google.com/github/RanjaneSiddhesh/genai/blob/main/12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

agent = pipeline("text-generation", model="gpt2")

def ai_agent(name, message):
    response = agent(message, max_length=40, truncation=True)[0]['generated_text']
    print(f"{name}: {response}\n")
    return response

msg = "Hello! What do you think about AI?"
for i in range(1):
    msg = ai_agent("Agent 1", msg)
    msg = ai_agent("Agent 2",msg)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Agent 1: Hello! What do you think about AI?
#
# The main concern right now is that the world of AI is so complex and so complex, that it is hard to explain the details of it. For example, it is difficult to understand how the world works, how it works in the real world, and how it works on mobile devices. It is not easy to understand what is going on on the computer when it is in a real life situation.
#
# What we are working on now is going to be a very flexible, complex, and high-level AI system that can be used on a wide range of platforms. We are looking at the use of a variety of algorithms and systems to do this. The problem is that there is only so many ways to do this.
#
# What's the current state of AI?
#
# We are working with a number of teams working on a variety of AI applications that are trying to understand and automate our world. We are doing this through a series of experiments. We are working on ways to create a more efficient AI system that can work on a wide range of platforms. We are also working on new ways to understand and automate the world of AI.
#
# What are your thoughts on AI?
#
# I think it's a big part of the future of AI
#
# Agent 2: Hello! What do you think about AI?
#
# The main concern right now is that the world of AI is so complex and so complex, that it is hard to explain the details of it. For example, it is difficult to understand how the world works, how it works in the real world, and how it works on mobile devices. It is not easy to understand what is going on on the computer when it is in a real life situation.
#
# What we are working on now is going to be a very flexible, complex, and high-level AI system that can be used on a wide range of platforms. We are looking at the use of a variety of algorithms and systems to do this. The problem is that there is only so many ways to do this.
#
# What's the current state of AI?
#
# We are working with a number of teams working on a variety of AI applications that are trying to understand and automate our world. We are doing this through a series of experiments. We are working on ways to create a more efficient AI system that can work on a wide range of platforms. We are also working on new ways to understand and automate the world of AI.
#
# What are your thoughts on AI?
#
# I think it's a big part of the future of AI So we have to start to think about how to solve this problem.
#
# We have to realize that it is not enough to just describe everything. We have to develop new kinds of AI that are so complex and complex that you can't even tell.
#
# You said that you are worried about the future. How do you see the future? Do you foresee the future in a very specific way?
#
# It depends on what kind of AI we develop. We are still in the early stages, but we know that we will have to learn more about AI. We want to develop AI with great speed.
#
# Do you think the future is that of artificial intelligence?
#
# In a way, yes. But I think we should be careful about what we call the future of AI.
#
# Yes, I do. Because we are not thinking about the future of AI right now.
#
# You say that AI is so complex and complex that it has to be solved by human beings.
#
# We have to think about how to solve this problem.
#
# And if we do that, it will be interesting to see how the world of AI will evolve.
#
# I think that maybe the future of AI is very complicated. But I think it also depends
